# %%
#importing all the required libraries and classes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#reading the csv data
df = pd.read_csv("Apple stock.csv")

# %%
df = df[['Total Trade Quantity', 'Turnover (Lacs)']]  # choosing columns
df.columns = ['volume', 'turnover'] #renaming columns

# %%
#divide data into dependant and independant features in an array
x=np.array(df['volume']).reshape(-1, 1) #independant variable
y=np.array(df['turnover']) #dependant variable
#splitting data into train and test
#30% testing, 70% training
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
#creating model and fit it
model = LinearRegression()
model.fit(x_train, y_train)
#the actual vs predicted values
y_pred = model.predict(x_test)
result = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(result)
print('The accuracy of the model:', model.score(x_test, y_test))
# Out:
#        Actual     Predicted
# 0     2523.61   3138.563968
# 1     9730.60   9626.611480
# 2     4331.70   3302.870762
# 3     6862.75   4968.489632
# 4     2943.20   3916.694377
# ..        ...           ...
# 366   2068.14   2153.251204
# 367   6228.57   8384.328777
# 368   1119.05    971.487546
# 369   5318.02   7176.080466
# 370  14389.22  11407.675278
#
# [371 rows x 2 columns]
# The accuracy of the model: 0.8892186257617024

# %%
#visualization
plt.scatter(x_test, y_test, color='r')
plt.plot(x_test, y_pred, color='k')
plt.title('volume vs turnover')
plt.xlabel('volume')
plt.ylabel('turnover')
plt.show()
